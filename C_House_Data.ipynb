# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
#%matplotlib inline
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
house_sales=pd.read_csv('kc_house_data.csv')
house_sales.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
house_sales.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
house_sales['sum']=house_sales['price']
house_sales.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view    ...     sqft_above  sqft_basement  \
# 0      5650     1.0           0     0    ...           1180              0
# 1      7242     2.0           0     0    ...           2170            400
# 2     10000     1.0           0     0    ...            770              0
# 3      5000     1.0           0     0    ...           1050            910
# 4      8080     1.0           0     0    ...           1680              0
#
# ...

# %%
s1=house_sales.drop(['price'],axis=1)
s1.head()
# Out:
#            id             date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520  20141013T000000         3       1.00         1180      5650
# 1  6414100192  20141209T000000         3       2.25         2570      7242
# 2  5631500400  20150225T000000         2       1.00          770     10000
# 3  2487200875  20141209T000000         4       3.00         1960      5000
# 4  1954400510  20150218T000000         3       2.00         1680      8080
#
#    floors  waterfront  view  condition    ...     sqft_above  sqft_basement  \
# 0     1.0           0     0          3    ...           1180              0
# 1     2.0           0     0          3    ...           2170            400
# 2     1.0           0     0          3    ...            770              0
# 3     1.0           0     0          5    ...           1050            910
# 4     1.0           0     0          3    ...           1680              0
#
# ...

# %%
s2=s1.drop(['date'],axis=1)
s2.head()
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  7129300520         3       1.00         1180      5650     1.0           0
# 1  6414100192         3       2.25         2570      7242     2.0           0
# 2  5631500400         2       1.00          770     10000     1.0           0
# 3  2487200875         4       3.00         1960      5000     1.0           0
# 4  1954400510         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
x=s2.loc[:,"bedrooms":"sqft_lot15"]
y=s2["sum"]

# %%
model=LinearRegression()
model.fit(pd.DataFrame(x),y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
poly=PolynomialFeatures(degree=3,interaction_only=False)

# %%
xx=poly.fit_transform(pd.DataFrame(x))
print(xx)
# Out:
# [[1.00000000e+00 3.00000000e+00 1.00000000e+00 ... 1.01451400e+10
#   4.27761500e+10 1.80362125e+11]
#  [1.00000000e+00 3.00000000e+00 2.25000000e+00 ... 2.18177479e+10
#   9.86188025e+10 4.45768658e+11]
#  [1.00000000e+00 2.00000000e+00 1.00000000e+00 ... 5.96459008e+10
#   1.76788696e+11 5.23996494e+11]
#  ...
#  [1.00000000e+00 2.00000000e+00 7.50000000e-01 ... 2.08808280e+09
#   4.10860998e+09 8.08429434e+09]
#  [1.00000000e+00 3.00000000e+00 2.50000000e+00 ... 2.55868470e+09
#   2.33548029e+09 2.13174690e+09]
#  [1.00000000e+00 2.00000000e+00 7.50000000e-01 ... 1.41182280e+09
#   1.87827798e+09 2.49884629e+09]]

# %%
model=LinearRegression()
model.fit(xx,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.score(xx,y)
# Out:
# 0.8646773649741263

# %%
x.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180      5650     1.0           0     0
# 1         3       2.25         2570      7242     2.0           0     0
# 2         2       1.00          770     10000     1.0           0     0
# 3         4       3.00         1960      5000     1.0           0     0
# 4         3       2.00         1680      8080     1.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          3      7        1180              0      1955             0
# 1          3      7        2170            400      1951          1991
# 2          3      6         770              0      1933             0
# 3          5      7        1050            910      1965             0
# 4          3      8        1680              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
xt=x.loc[1:5,:]
xt
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 1         3       2.25         2570      7242     2.0           0     0
# 2         2       1.00          770     10000     1.0           0     0
# 3         4       3.00         1960      5000     1.0           0     0
# 4         3       2.00         1680      8080     1.0           0     0
# 5         4       4.50         5420    101930     1.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 1          3      7        2170            400      1951          1991
# 2          3      6         770              0      1933             0
# 3          5      7        1050            910      1965             0
# 4          3      8        1680              0      1987             0
# 5          3     11        3890           1530      2001             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
xxt=poly.fit_transform(pd.DataFrame(xt))
yt=model.predict(xxt)
yt
# Out:
# array([ 496612.74962997,  547053.37409592,  434485.14748764,
#         453675.82413864, 1306381.92194748])

# %%
x=pd.DataFrame(x)
y=pd.DataFrame(y)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
model.fit(x_train,y_train)
model.coef_
r2_score(y_train,model.predict(x_train))
# Out:
# 0.6923697165968319

# %%
n1=house_sales.drop(['date'],axis=1)
n1.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %%
n1.isna().sum()
# Out:
# id               0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
n1.corr().nlargest(21,'price')
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# sum           -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# sqft_above    -0.010842  0.605567  0.477600   0.685342     0.876597  0.183512
# sqft_living15 -0.002901  0.585379  0.391638   0.568634     0.756420  0.144608
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# sqft_basement -0.005151  0.323816  0.303093   0.283770     0.435043  0.015286
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# lat           -0.001891  0.307003 -0.008931   0.024573     0.052529 -0.085683
# ...

# %%
n1
# Out:
#                id      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520   221900.0         3       1.00         1180      5650
# 1      6414100192   538000.0         3       2.25         2570      7242
# 2      5631500400   180000.0         2       1.00          770     10000
# 3      2487200875   604000.0         4       3.00         1960      5000
# 4      1954400510   510000.0         3       2.00         1680      8080
# 5      7237550310  1225000.0         4       4.50         5420    101930
# 6      1321400060   257500.0         3       2.25         1715      6819
# 7      2008000270   291850.0         3       1.50         1060      9711
# 8      2414600126   229500.0         3       1.00         1780      7470
# 9      3793500160   323000.0         3       2.50         1890      6560
# 10     1736800520   662500.0         3       2.50         3560      9796
# 11     9212900260   468000.0         2       1.00         1160      6000
# ...

# %%
n1['sum']=n1['price']
n1.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition    ...     sqft_above  sqft_basement  yr_built  \
# 0           0     0          3    ...           1180              0      1955
# 1           0     0          3    ...           2170            400      1951
# 2           0     0          3    ...            770              0      1933
# 3           0     0          5    ...           1050            910      1965
# 4           0     0          3    ...           1680              0      1987
#
# ...

# %%
n2=n1.drop(['price'],axis=1)
n2.head()
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  7129300520         3       1.00         1180      5650     1.0           0
# 1  6414100192         3       2.25         2570      7242     2.0           0
# 2  5631500400         2       1.00          770     10000     1.0           0
# 3  2487200875         4       3.00         1960      5000     1.0           0
# 4  1954400510         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
#n3=n2.drop(['id'],axis=1)
#n3=n2.drop(['zipcode'],axis=1)
#n3=n2.drop(['sqft_lot'],axis=1)
#n3=n2.drop(['id','sqft_above','sqft_basement'],axis=1)
#n3.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180      5650     1.0           0     0
# 1         3       2.25         2570      7242     2.0           0     0
# 2         2       1.00          770     10000     1.0           0     0
# 3         4       3.00         1960      5000     1.0           0     0
# 4         3       2.00         1680      8080     1.0           0     0
#
#    condition  grade  yr_built  yr_renovated  zipcode      lat     long  \
# 0          3      7      1955             0    98178  47.5112 -122.257
# 1          3      7      1951          1991    98125  47.7210 -122.319
# 2          3      6      1933             0    98028  47.7379 -122.233
# 3          5      7      1965             0    98136  47.5208 -122.393
# 4          3      8      1987             0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15       sum
# 0           1340        5650  221900.0
# ...

# %%
x=n3.loc[:,"bedrooms":"sqft_living15"]
y=n3["sum"]

# %%
model=LinearRegression()

# %%
x=pd.DataFrame(x)
y=pd.DataFrame(y)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
model.fit(x_train,y_train)
model.coef_
r2_score(y_train,model.predict(x_train))
# Out:
# 0.7026341256943536

# %%
n3['recent_year']=0
n3.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180      5650     1.0           0     0
# 1         3       2.25         2570      7242     2.0           0     0
# 2         2       1.00          770     10000     1.0           0     0
# 3         4       3.00         1960      5000     1.0           0     0
# 4         3       2.00         1680      8080     1.0           0     0
#
#    condition  grade  yr_built  yr_renovated  zipcode      lat     long  \
# 0          3      7      1955             0    98178  47.5112 -122.257
# 1          3      7      1951          1991    98125  47.7210 -122.319
# 2          3      6      1933             0    98028  47.7379 -122.233
# 3          5      7      1965             0    98136  47.5208 -122.393
# 4          3      8      1987             0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15       sum  recent_year
# 0           1340        5650  221900.0            0
# ...

# %%
for i in range(len(n3)):
    if(n3.loc[i,'yr_renovated']>n3.loc[i,'yr_built']):
        n3.loc[i,'recent_year']=2018-n3.loc[i,'yr_renovated']
    else:
        n3.loc[i,'recent_year']=2018-n3.loc[i,'yr_built']

# %%
n3['amount']=n3['sum']
n3.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180      5650     1.0           0     0
# 1         3       2.25         2570      7242     2.0           0     0
# 2         2       1.00          770     10000     1.0           0     0
# 3         4       3.00         1960      5000     1.0           0     0
# 4         3       2.00         1680      8080     1.0           0     0
#
#    condition  grade  yr_built  yr_renovated  zipcode      lat     long  \
# 0          3      7      1955             0    98178  47.5112 -122.257
# 1          3      7      1951          1991    98125  47.7210 -122.319
# 2          3      6      1933             0    98028  47.7379 -122.233
# 3          5      7      1965             0    98136  47.5208 -122.393
# 4          3      8      1987             0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15       sum  recent_year    amount
# ...

# %%
n4=n3.drop(['yr_built'],axis=1)
n4.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180      5650     1.0           0     0
# 1         3       2.25         2570      7242     2.0           0     0
# 2         2       1.00          770     10000     1.0           0     0
# 3         4       3.00         1960      5000     1.0           0     0
# 4         3       2.00         1680      8080     1.0           0     0
#
#    condition  grade  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0          3      7             0    98178  47.5112 -122.257           1340
# 1          3      7          1991    98125  47.7210 -122.319           1690
# 2          3      6             0    98028  47.7379 -122.233           2720
# 3          5      7             0    98136  47.5208 -122.393           1360
# 4          3      8             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15       sum  recent_year    amount
# ...

# %%
n5=n4.drop(['yr_renovated'],axis=1)
n5.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180      5650     1.0           0     0
# 1         3       2.25         2570      7242     2.0           0     0
# 2         2       1.00          770     10000     1.0           0     0
# 3         4       3.00         1960      5000     1.0           0     0
# 4         3       2.00         1680      8080     1.0           0     0
#
#    condition  grade  zipcode      lat     long  sqft_living15  sqft_lot15  \
# 0          3      7    98178  47.5112 -122.257           1340        5650
# 1          3      7    98125  47.7210 -122.319           1690        7639
# 2          3      6    98028  47.7379 -122.233           2720        8062
# 3          5      7    98136  47.5208 -122.393           1360        5000
# 4          3      8    98074  47.6168 -122.045           1800        7503
#
#         sum  recent_year    amount
# 0  221900.0           63  221900.0
# ...

# %%
del n5['sum']

# %%
n5.corr().nlargest(19,'amount')
# Out:
#                bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# amount         0.308350   0.525138     0.702035  0.089661  0.256794
# sqft_living    0.576671   0.754665     1.000000  0.172826  0.353949
# grade          0.356967   0.664983     0.762704  0.113621  0.458183
# sqft_living15  0.391638   0.568634     0.756420  0.144608  0.279885
# bathrooms      0.515884   1.000000     0.754665  0.087740  0.500653
# view           0.079532   0.187737     0.284611  0.074710  0.029444
# bedrooms       1.000000   0.515884     0.576671  0.031703  0.175429
# lat           -0.008931   0.024573     0.052529 -0.085683  0.049614
# waterfront    -0.006582   0.063744     0.103818  0.021604  0.023698
# floors         0.175429   0.500653     0.353949 -0.005201  1.000000
# sqft_lot       0.031703   0.087740     0.172826  1.000000 -0.005201
# sqft_lot15     0.029244   0.087175     0.183286  0.718557 -0.011269
# condition      0.028472  -0.124982    -0.058753 -0.008958 -0.263768
# ...

# %%
n5.corr().tail(1)
# Out:
#         bedrooms  bathrooms  sqft_living  sqft_lot    floors  waterfront  \
# amount   0.30835   0.525138     0.702035  0.089661  0.256794    0.266369
#
#             view  condition     grade   zipcode       lat      long  \
# amount  0.397293   0.036362  0.667434 -0.053203  0.307003  0.021626
#
#         sqft_living15  sqft_lot15  recent_year  amount
# amount       0.585379    0.082447    -0.105755     1.0

# %%
#x=n5.loc[:,"bedrooms":"recent_year"]
#y=n5["amount"]

# %%
model=LinearRegression()

# %%
x=pd.DataFrame(x)
y=pd.DataFrame(y)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
model.fit(x_train,y_train)
model.coef_
r2_score(y_train,model.predict(x_train))
# Out:
# 0.6923697165968319
